# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle as pkl
import matplotlib.cm as cm
import numpy as np

# %%
# handle pickle IO
def read_pickle(pickle_name):
    path = "../pickles/"
    return pkl.load(open(path+pickle_name, "rb"))

def dump_pickle(obj, pickle_name):
    path = "../pickles/"
    pkl.dump(obj, open(path+pickle_name, "wb"))

# %%
df = read_pickle("cleaned_data.pkl")

# %%
words = []
for doc in df['texts']:
    for w in doc:
        words.append(w)
distinct_words = list(set(words))

# %%
print len(words)
print len(distinct_words)
# Out:
# 71738
# 4767

# %%
freq_dict = dict( zip(distinct_words, [0]*len(words)) )

# %%
for w in words:
    freq_dict[w] += 1

# %%
# Out:
# {u'workingduring': 1, u'secondly': 2, u'decompressed': 19, u'interzone': 14, u'limited': 4, u'moweset': 2, u'untrust': 11, u'child': 4, u'dynamic': 137, u'yellow': 1, u'four': 2, u'facilities': 1, u'httpsfjern': 2, u'uauth': 37, u'firt': 1, u'consists': 2, u'oldest': 1, u'integrity': 111, u'skeleton': 1, u'whose': 3, u'pedro': 1, u'aug': 8, u'whereever': 1, u'segments': 1, u'ecdh': 1, u'presents': 1, u'mate': 5, u'tweek': 1, u'pmtu': 1, u'aux': 17, u'sorry': 7, u'greentunnel': 1, u'bare': 1, u'placed': 2, u'ciscolearner': 1, u'comeup': 1, u'updated': 8, u'callin': 6, u'performs': 1, u'hdr': 9, u'outsidebut': 1, u'activation': 14, u'regional': 1, u'instad': 1, u'connects': 21, u'sslvpnclient': 1, u'handling': 1, u'every': 18, u'enterit': 1, u'dhcp': 81, u'encipherment': 2, u'affect': 4, u'month': 3, u'lifetimeout': 1, u'lumia': 2, u'onepublic': 1, u'school': 1, u'internally': 2, u'publicly': 1, u'failoverpart': 1, u'cme': 1, u'cmd': 2, u'solution': 43, u'database': 5, u'ciscofolder': 1, u'withvpn': 1, u'unauthorised': 1, u'heading': 2, u'possiblity': 1, u'force': 5, u'throught': 1, u'phones': 7, u'warns': 1, u'guidelines': 3, u'direct': 6, u'feasibility': 1, u'second': 22, u'street': 1, u'sabeen': 1, u'correlator': 7, u'nbma': 44, u'implemented': 4, u'specs': 2, u'machines': 9, u'even': 33, u'established': 17, u'errors': 28, u'hide': 3, u'preferences': 3, u'softrware': 1, u'saved': 16, u'selected': 5, u'near': 2, u'supplied': 3, u'vpnand': 1, u'succeeds': 1, u'keymysecretkey': 1, u'establishes': 1, u'designing': 1, u'new': 215, u'net': 5, u'reluctant': 1, u'ever': 4, u'ecm': 1, u'dfltaccesspolicy': 36, u'told': 4, u'anyyconect': 1, u'ciscoanyconnectapex': 1, u'million': 1, u